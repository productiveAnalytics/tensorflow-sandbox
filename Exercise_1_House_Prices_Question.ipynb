# %% [markdown]
# In this exercise you'll try to build a neural network that predicts the price of a house according to a simple formula.
#
# So, imagine if house pricing was as easy as a house costs 50k + 50k per bedroom, so that a 1 bedroom house costs 100k, a 2 bedroom house costs 150k etc.
#
# How would you create a neural network that learns this relationship so that it would predict a 7 bedroom house as costing close to 400k etc.
#
# Hint: Your network might work better if you scale the house price down. You don't have to give the answer 400...it might be better to create something that predicts the number 4, and then your answer is in the 'hundreds of thousands' etc.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
model = tf.keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])
model.compile(optimizer='sgd', loss='MSE')
xs = np.array([7,9,7,2,10,1,10,3,5,5,5,2,2,8,7,10,7,2,1,4,1,7,2,2,3,2,9,5,4,8,4,3,5,2,6,4,7,2,4,3,3,3,4,8,7,3,4,1,10,3,10,1,5,4,1,7,3,8,9,8,4,9,9,6,1,2,3,8,5,3,10,6,4,6,5,3,4,9,8,3,3,9,9,2,2,9,7,9,9,6,10,2,3,8,7,9,5,7,4],dtype=int)
ys = np.array([453,533,455,168,586,151,582,252,338,325,374,211,199,488,433,582,455,198,159,288,158,432,204,209,229,204,519,348,304,505,283,257,366,214,411,285,452,178,330,272,250,256,307,491,448,236,271,176,611,258,583,145,346,302,137,450,272,500,543,482,303,575,561,376,136,196,261,501,341,224,573,395,296,402,358,236,295,551,508,233,243,547,548,199,188,546,450,533,558,391,603,219,249,511,422,558,363,453,312],dtype=int)
model.fit(xs,ys,epochs=1000)
print('Expected price for 7 bedroom house: ', (100+7*50),' Predicted Price: ',model.predict([7]))
# Out:
# Epoch 1/1000
# 99/99 [==============================] - 0s 1ms/sample - loss: 54434.7035
# Epoch 2/1000
# 99/99 [==============================] - 0s 115us/sample - loss: 1995.6795
# Epoch 3/1000
# 99/99 [==============================] - 0s 80us/sample - loss: 2309.9912
# Epoch 4/1000
# 99/99 [==============================] - 0s 85us/sample - loss: 1925.4004
# Epoch 5/1000
# 99/99 [==============================] - 0s 85us/sample - loss: 2733.1372
# Epoch 6/1000
# 99/99 [==============================] - 0s 75us/sample - loss: 1771.3159
# Epoch 7/1000
# 99/99 [==============================] - 0s 79us/sample - loss: 1762.8848
# Epoch 8/1000
# 99/99 [==============================] - 0s 78us/sample - loss: 1832.5127
# Epoch 9/1000
# 99/99 [==============================] - 0s 100us/sample - loss: 1741.9186
# Epoch 10/1000
# 99/99 [==============================] - 0s 102us/sample - loss: 1652.7634
# Epoch 11/1000
# ...

# %%
import csv
import random

# %%
BASE_HOUSE_PRICE = 100

def generate_house_price(bedroom_count: int) -> int:
  variance_start = -(random.randint(0,33))
  variance_end = random.randint(0,33)
  variance = random.randint(variance_start, variance_end)
  print('Variance between (',variance_start,'...', variance_end,') is ', variance)
  house_price = BASE_HOUSE_PRICE + (bedroom_count * 50) + variance
  print('Bedrooms: ', bedroom_count,' Price= ', house_price)
  return house_price

bedroom_cnt = random.randint(1,10)
print(generate_house_price(bedroom_cnt))
# Out:
# Variance between ( -26 ... 20 ) is  -11
# Bedrooms:  4  Price=  289
# 289

# %%
with open('house_price_data.csv', 'w') as csvfile:
  csvFileWriter =  csv.writer(csvfile, delimiter=',',quotechar='|', quoting=csv.QUOTE_MINIMAL)
  csvFileWriter.writerow(['#', 'Bedrooms', 'Price'])
  for itr in range(1, 100):
    bdrm_count = random.randint(1,10)
    csvFileWriter.writerow([itr, bdrm_count, generate_house_price(bdrm_count)])
# Out:
# Variance between ( -33 ... 6 ) is  -1
# Bedrooms:  3  Price=  249
# Variance between ( -17 ... 4 ) is  2
# Bedrooms:  4  Price=  302
# Variance between ( -9 ... 17 ) is  3
# Bedrooms:  10  Price=  603
# Variance between ( -23 ... 8 ) is  -5
# Bedrooms:  4  Price=  295
# Variance between ( -30 ... 23 ) is  -18
# Bedrooms:  3  Price=  232
# Variance between ( -26 ... 10 ) is  7
# Bedrooms:  7  Price=  457
# Variance between ( -11 ... 4 ) is  -7
# Bedrooms:  5  Price=  343
# Variance between ( -1 ... 12 ) is  7
# Bedrooms:  7  Price=  457
# Variance between ( -17 ... 27 ) is  21
# Bedrooms:  4  Price=  321
# Variance between ( -16 ... 27 ) is  7
# Bedrooms:  1  Price=  157
# Variance between ( -14 ... 31 ) is  -13
# Bedrooms:  6  Price=  387
# Variance between ( -1 ... 7 ) is  4
# Bedrooms:  1  Price=  154
# Variance between ( -2 ... 9 ) is  -1
# Bedrooms:  5  Price=  349
# Variance between ( -13 ... 2 ) is  -12
# Bedrooms:  3  Price=  238
# Variance between ( -6 ... 25 ) is  14
# ...
